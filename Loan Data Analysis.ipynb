# %% [markdown]
# # Loan Data Analysis Project

# %% [markdown]
# ### importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### read csv file

# %%
df=pd.read_csv("D:/DATA SCIENCE LEC PDF/Python_projects/Loan_data_analysis_project/Loan_dataset.csv")

# %%
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
df.shape
# Out:
# (100514, 19)

# %%
df.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100000 non-null  object
#  1   Customer ID                   100000 non-null  object
#  2   Loan Status                   100000 non-null  object
#  3   Current Loan Amount           100000 non-null  float64
#  4   Term                          100000 non-null  object
#  5   Credit Score                  80846 non-null   float64
#  6   Annual Income                 80846 non-null   float64
#  7   Years in current job          95778 non-null   object
#  8   Home Ownership                100000 non-null  object
#  9   Purpose                       100000 non-null  object
#  10  Monthly Debt                  100000 non-null  float64
#  11  Years of Credit History       100000 non-null  float64
# ...

# %% [markdown]
# ### null value treatment

# %%
for i in df.columns:
    if df[i].dtypes==object:
        df[i]=df[i].fillna(df[i].mode()[0])
    else:
        df[i]=df[i].fillna(df[i].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100514 entries, 0 to 100513
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       100514 non-null  object
#  1   Customer ID                   100514 non-null  object
#  2   Loan Status                   100514 non-null  object
#  3   Current Loan Amount           100514 non-null  float64
#  4   Term                          100514 non-null  object
#  5   Credit Score                  100514 non-null  float64
#  6   Annual Income                 100514 non-null  float64
#  7   Years in current job          100514 non-null  object
#  8   Home Ownership                100514 non-null  object
#  9   Purpose                       100514 non-null  object
#  10  Monthly Debt                  100514 non-null  float64
#  11  Years of Credit History       100514 non-null  float64
# ...

# %%
# average current loan amount for each loan status
df.groupby(by='Loan Status')['Current Loan Amount'].mean()
# Out:
# Loan Status
# Charged Off    3.249752e+05
# Fully Paid     1.508485e+07
# Name: Current Loan Amount, dtype: float64

# %%
#  how credit score vary with the annual income
sns.scatterplot(data=df,x='Credit Score',y='Annual Income')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Annual Income'>

# %%
# correlation between the number of open accounts and the current credit balance
sns.heatmap(df[['Number of Open Accounts','Current Credit Balance']].corr(),annot=True)
# Out:
# <Axes: >

# %%
 # distribution of credit scores across different home ownership types
sns.boxplot(data=df,x='Home Ownership',y='Credit Score')
# Out:
# <Axes: xlabel='Home Ownership', ylabel='Credit Score'>

# %%
# annual income differ for different purposes of loans
df.groupby(by='Purpose')['Annual Income'].sum().plot(kind='barh')
# Out:
# <Axes: ylabel='Purpose'>

# %%
# average monthly debt for each term (short-term vs. long-term)
df.groupby(by='Term')['Monthly Debt'].mean()
# Out:
# Term
# Long Term     21585.664968
# Short Term    17282.627716
# Name: Monthly Debt, dtype: float64

# %%
# correlation between years of credit history and the current credit balance
sns.heatmap(df[['Years of Credit History','Current Credit Balance']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# credit score vary with the years in the current job
sns.boxplot(data=df,x='Years in current job',y='Credit Score')
# Out:
# <Axes: xlabel='Years in current job', ylabel='Credit Score'>

# %%
# relationship between the number of credit problems and the number of open accounts
sns.heatmap(df[['Number of Credit Problems','Number of Open Accounts']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# distribution of annual income across different loan statuses
df.groupby(by='Loan Status')['Annual Income'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Annual Income'>

# %%
# correlation between the current loan amount and the number of open accounts
sns.heatmap(df[['Current Loan Amount','Number of Open Accounts']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# monthly debt vary with the years of credit history
sns.scatterplot(data=df,x='Years of Credit History',y='Monthly Debt')
# Out:
# <Axes: xlabel='Years of Credit History', ylabel='Monthly Debt'>

# %%
# average annual income for each purpose of loan 
df.groupby(by='Purpose')['Annual Income'].mean()
# Out:
# Purpose
# Business Loan           1.551922e+06
# Buy House               1.475756e+06
# Buy a Car               1.250439e+06
# Debt Consolidation      1.365614e+06
# Educational Expenses    1.123807e+06
# Home Improvements       1.612022e+06
# Medical Bills           1.403618e+06
# Other                   1.354084e+06
# Take a Trip             1.246710e+06
# major_purchase          1.420318e+06
# moving                  1.555859e+06
# other                   1.301598e+06
# renewable_energy        1.454647e+06
# small_business          1.518164e+06
# vacation                1.217108e+06
# wedding                 1.444052e+06
# Name: Annual Income, dtype: float64

# %%
# credit score vary with the number of credit problems
sns.scatterplot(data=df,x='Number of Credit Problems',y='Credit Score')
# Out:
# <Axes: xlabel='Number of Credit Problems', ylabel='Credit Score'>

# %%
# correlation between the number of credit problems and the current credit balance
sns.heatmap(df[['Number of Credit Problems','Current Credit Balance']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# distribution of current loan amounts across different home ownership types
df.groupby(by='Home Ownership')['Current Loan Amount'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Current Loan Amount'>

# %%
# annual income vary with the years in the current job
sns.scatterplot(data=df,x='Years in current job',y='Annual Income')
# Out:
# <Axes: xlabel='Years in current job', ylabel='Annual Income'>

# %%
# correlation between the current loan amount and the monthly debt 
sns.heatmap(df[['Current Loan Amount','Monthly Debt']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# average monthly debt for each home ownership type
df.groupby(by='Home Ownership')['Monthly Debt'].mean()
# Out:
# Home Ownership
# HaveMortgage     18541.776822
# Home Mortgage    21044.747337
# Own Home         17060.082101
# Rent             15796.777284
# Name: Monthly Debt, dtype: float64

# %%
# credit score vary with the number of open accounts
sns.scatterplot(data=df,x='Number of Open Accounts',y='Credit Score')
# Out:
# <Axes: xlabel='Number of Open Accounts', ylabel='Credit Score'>

# %%
# distribution of credit scores across different loan statuses
df.groupby(by='Loan Status')['Credit Score'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Credit Score'>

# %%
# correlation between the current loan amount and the years of credit history
sns.heatmap(df[['Current Loan Amount','Years of Credit History']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# How monthly debt vary with the number of credit problems
sns.scatterplot(data=df,x='Number of Credit Problems',y='Monthly Debt')
# Out:
# <Axes: xlabel='Number of Credit Problems', ylabel='Monthly Debt'>

# %%
# average current loan amount for each purpose of loan 
df.groupby(by='Purpose')['Current Loan Amount'].mean()
# Out:
# Purpose
# Business Loan           7.837789e+06
# Buy House               1.106036e+07
# Buy a Car               1.414682e+07
# Debt Consolidation      1.180652e+07
# Educational Expenses    1.428536e+07
# Home Improvements       1.252117e+07
# Medical Bills           1.179902e+07
# Other                   1.253627e+07
# Take a Trip             1.111667e+07
# major_purchase          1.298956e+07
# moving                  1.350072e+07
# other                   1.059243e+07
# renewable_energy        1.975534e+05
# small_business          9.484232e+06
# vacation                7.058680e+06
# wedding                 1.760299e+07
# Name: Current Loan Amount, dtype: float64

# %%
# 25.How does the credit score vary with the current credit balance?
sns.scatterplot(data=df,x='Current Credit Balance',y='Credit Score')
# Out:
# <Axes: xlabel='Current Credit Balance', ylabel='Credit Score'>

# %%
# correlation between the annual income and the current credit balance
sns.heatmap(df[['Annual Income','Current Credit Balance']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# distribution of annual income across different terms (short-term vs. long-term)
df.groupby(by='Term')['Annual Income'].sum().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Annual Income'>

# %%
#  credit score vary with the number of credit problems
sns.scatterplot(data=df,x='Number of Credit Problems',y='Credit Score')
# Out:
# <Axes: xlabel='Number of Credit Problems', ylabel='Credit Score'>

# %%
#  correlation between the current loan amount and the number of credit problems
sns.heatmap(df[['Current Loan Amount','Number of Credit Problems']].corr(),annot=True)
# Out:
# <Axes: >

# %%
# relationship between the number of open accounts and the years of credit history
sns.scatterplot(data=df,x='Years of Credit History',y='Number of Open Accounts')
# Out:
# <Axes: xlabel='Years of Credit History', ylabel='Number of Open Accounts'>
